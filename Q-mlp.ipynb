# %% [markdown]
# # 0. Install and import the libraries

# %%
'''!pip install numpy
# !pip install tensorflow
# !pip install keras
# !pip install matplotlib'''
# Out:
# '!pip install numpy\n!pip install tensorflow\n!pip install keras\n!pip install matplotlib'

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set Random Seed for Reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)
batch_size = 64

# %% [markdown]
# # 2. Load and Preprocess the MNIST Dataset

# %%
# Load the MNIST dataset
(x_train, y_train_orig), (x_test, y_test_orig) = keras.datasets.mnist.load_data()

# Normalize the images to [0, 1] range and flatten them
x_train = x_train.astype('float32') / 255.0
x_train_flat = x_train.reshape(-1, 28 * 28)
x_test = x_test.astype('float32') / 255.0
x_test_flat = x_test.reshape(-1, 28 * 28)

# Convert labels to one-hot encoded vectors
num_classes = 10
y_train = keras.utils.to_categorical(y_train_orig, num_classes)
y_test = keras.utils.to_categorical(y_test_orig, num_classes)

# %% [markdown]
# # 3. Hyperparameters

# %%
''' TODO: Adjust the following parameters with different values. Save the plots and test results for each setup.
    TODO: write a report about your findings from varying the parameters and their effect on overall performance. '''



# layer: [128], [256, 256], ... .

#prof
#learning rate: 0.1, 0.01

#epoch: 5, 10, 50
#number of layers [128], [128, 128]
#hidden units: [256], [256, 256]

learning_rate = 0.01
num_epochs = 50
hidden_layers = [256, 256]

# %% [markdown]
# # 4. Define the Neural Network Model

# %%
def create_mlp_model(input_size, hidden_layers, output_size):
    model = keras.Sequential()

    # Input layer is defined by specifying input_shape in the first layer
    for i, units in enumerate(hidden_layers):
        if i == 0:
            # First hidden layer with input shape specified
            model.add(layers.Dense(units, activation='relu', input_shape=(input_size,)))
        else:
            # Subsequent hidden layers
            model.add(layers.Dense(units, activation='relu'))

    # Output layer with softmax activation for multi-class classification
    model.add(layers.Dense(output_size, activation='softmax'))

    return model

# Model parameters
input_size = 28 * 28  # MNIST images are 28x28 pixels
output_size = num_classes  # 10 classes for digits 0-9

# Create the model
model = create_mlp_model(input_size, hidden_layers, output_size)
# Out:
# C:\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # 5. Compile the Model

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 6. Train the Model

# %%
history = model.fit(
    x_train_flat, y_train,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_split=0.1,  # Use 10% of training data for validation
    verbose=1
)
# Out:
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6472 - loss: 1.3567 - val_accuracy: 0.9083 - val_loss: 0.3544
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8864 - loss: 0.4000 - val_accuracy: 0.9252 - val_loss: 0.2725
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9065 - loss: 0.3257 - val_accuracy: 0.9315 - val_loss: 0.2394
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9166 - loss: 0.2880 - val_accuracy: 0.9388 - val_loss: 0.2177
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9239 - loss: 0.2614 - val_accuracy: 0.9443 - val_loss: 0.2006
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9309 - loss: 0.2401 - val_accuracy: 0.9492 - val_loss: 0.1864
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9360 - loss: 0.2221 - val_accuracy: 0.9523 - val_loss: 0.1743
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9405 - loss: 0.2065 - val_accuracy: 0.9555 - val_loss: 0.1640
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9445 - loss: 0.1929 - val_accuracy: 0.9597 - val_loss: 0.1550
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9482 - loss: 0.1808 - val_accuracy: 0.9617 - val_loss: 0.1471
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9518 - loss: 0.1699 - val_accuracy: 0.9637 - val_loss: 0.1402
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9544 - loss: 0.1602 - val_accuracy: 0.9645 - val_loss: 0.1342
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9570 - loss: 0.1514 - val_accuracy: 0.9653 - val_loss: 0.1289
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9592 - loss: 0.1435 - val_accuracy: 0.9655 - val_loss: 0.1242
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9613 - loss: 0.1362 - val_accuracy: 0.9658 - val_loss: 0.1200
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9637 - loss: 0.1295 - val_accuracy: 0.9665 - val_loss: 0.1162
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9651 - loss: 0.1233 - val_accuracy: 0.9678 - val_loss: 0.1128
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9668 - loss: 0.1176 - val_accuracy: 0.9678 - val_loss: 0.1097
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9687 - loss: 0.1123 - val_accuracy: 0.9687 - val_loss: 0.1069
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9707 - loss: 0.1074 - val_accuracy: 0.9695 - val_loss: 0.1043
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9717 - loss: 0.1028 - val_accuracy: 0.9703 - val_loss: 0.1019
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9730 - loss: 0.0985 - val_accuracy: 0.9712 - val_loss: 0.0997
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9740 - loss: 0.0944 - val_accuracy: 0.9717 - val_loss: 0.0977
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9752 - loss: 0.0907 - val_accuracy: 0.9723 - val_loss: 0.0958
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9763 - loss: 0.0871 - val_accuracy: 0.9730 - val_loss: 0.0940
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9772 - loss: 0.0838 - val_accuracy: 0.9738 - val_loss: 0.0924
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9784 - loss: 0.0806 - val_accuracy: 0.9740 - val_loss: 0.0909
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9795 - loss: 0.0777 - val_accuracy: 0.9743 - val_loss: 0.0896
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9802 - loss: 0.0749 - val_accuracy: 0.9747 - val_loss: 0.0882
# Epoch 30/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9809 - loss: 0.0722 - val_accuracy: 0.9752 - val_loss: 0.0870
# Epoch 31/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9812 - loss: 0.0696 - val_accuracy: 0.9753 - val_loss: 0.0859
# Epoch 32/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9818 - loss: 0.0672 - val_accuracy: 0.9755 - val_loss: 0.0848
# Epoch 33/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9826 - loss: 0.0649 - val_accuracy: 0.9762 - val_loss: 0.0838
# Epoch 34/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9832 - loss: 0.0627 - val_accuracy: 0.9765 - val_loss: 0.0829
# Epoch 35/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9840 - loss: 0.0606 - val_accuracy: 0.9768 - val_loss: 0.0820
# Epoch 36/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9845 - loss: 0.0586 - val_accuracy: 0.9773 - val_loss: 0.0812
# Epoch 37/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9850 - loss: 0.0567 - val_accuracy: 0.9773 - val_loss: 0.0805
# Epoch 38/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9856 - loss: 0.0549 - val_accuracy: 0.9777 - val_loss: 0.0798
# Epoch 39/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9861 - loss: 0.0531 - val_accuracy: 0.9775 - val_loss: 0.0791
# Epoch 40/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9866 - loss: 0.0515 - val_accuracy: 0.9777 - val_loss: 0.0785
# Epoch 41/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9873 - loss: 0.0499 - val_accuracy: 0.9773 - val_loss: 0.0780
# Epoch 42/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9875 - loss: 0.0483 - val_accuracy: 0.9775 - val_loss: 0.0775
# Epoch 43/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9880 - loss: 0.0469 - val_accuracy: 0.9772 - val_loss: 0.0770
# Epoch 44/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9883 - loss: 0.0454 - val_accuracy: 0.9773 - val_loss: 0.0766
# Epoch 45/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9888 - loss: 0.0441 - val_accuracy: 0.9775 - val_loss: 0.0762
# Epoch 46/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9896 - loss: 0.0427 - val_accuracy: 0.9775 - val_loss: 0.0758
# Epoch 47/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9898 - loss: 0.0415 - val_accuracy: 0.9777 - val_loss: 0.0754
# Epoch 48/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9903 - loss: 0.0402 - val_accuracy: 0.9780 - val_loss: 0.0751
# Epoch 49/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9909 - loss: 0.0391 - val_accuracy: 0.9778 - val_loss: 0.0747
# Epoch 50/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9910 - loss: 0.0379 - val_accuracy: 0.9778 - val_loss: 0.0745

# %% [markdown]
# # 7. Evaluate the Model on Test Data

# %%
test_loss, test_accuracy = model.evaluate(x_test_flat, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 97.71%

# %% [markdown]
# # 8. Visualize Training History

# %%
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Test the Model on Random Input Data

# %%
# Select random samples from the test set
num_samples = 5
random_indices = np.random.choice(x_test.shape[0], num_samples, replace=False)
random_images = x_test[random_indices]
random_images_flat = x_test_flat[random_indices]
random_labels = y_test_orig[random_indices]

# Predict the labels of the random images
predictions = model.predict(random_images_flat)
predicted_labels = np.argmax(predictions, axis=1)

# Plot the random images along with predicted and true labels
plt.figure(figsize=(15, 3))
for i in range(num_samples):
    plt.subplot(1, num_samples, i+1)
    plt.imshow(random_images[i], cmap='gray')
    plt.title(f"True: {random_labels[i]}\nPredicted: {predicted_labels[i]}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
